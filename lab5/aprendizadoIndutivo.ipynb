# %% [markdown]
# # Criterio Prova

# %%
#pip install 
#pip install matplotlib
#pip install pandas

import pandas as pd
import numpy as np
from sklearn import tree, metrics
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from scipy.io import arff


# data,meta = arff.loadarff('./CriterioMedia.arff')
data,meta = arff.loadarff('./CriterioProvas.arff')

attributes = meta.names()
data_value = np.asarray(data)


percFalta = np.asarray(data['PercFalta']).reshape(-1,1)
notas1 = np.asarray(data['P1']).reshape(-1,1)
notas2 = np.asarray(data['P2']).reshape(-1,1)
features = np.concatenate((notas1, notas2 , percFalta),axis=1)
target = data['resultado']


Arvore = DecisionTreeClassifier(criterion='entropy').fit(features, target)

plt.figure(figsize=(10, 6.5))
tree.plot_tree(Arvore,feature_names=['P1', 'P2','PercFalta'],class_names=['Aprovado', 'Reprovado'], filled=True, rounded=True)
plt.show()

fig, ax = plt.subplots(figsize=(25, 10))
metrics.ConfusionMatrixDisplay.from_estimator(Arvore,features,target,display_labels=['Aprovado', 'Reprovado'], values_format='d', ax=ax)
plt.show()
# Out:
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# ...

# %% [markdown]
# # Bank

# %%
# %pip install matplotlib pandas scikit-learn

import pandas as pd
import numpy as np
from sklearn import tree, metrics
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from scipy.io import arff
from sklearn.preprocessing import LabelEncoder


# data,meta = arff.loadarff('./CriterioMedia.arff')
data,meta = arff.loadarff('./bank.arff')

attributes = meta.names()
data_value = np.asarray(data)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# " # Converte para DataFrame para facilitar a manipulação\ndf = pd.DataFrame(data)\n\n# Remove o prefixo 'b'' de strings binárias\ndf = df.applymap(lambda x: x.decode('utf-8') if isinstance(x, bytes) else x)\n\n# Converte as variáveis categóricas em numéricas usando LabelEncoder\nlabel_encoders = {}\nfor column in df.select_dtypes(include=['object']).columns:\n    le = LabelEncoder()\n    df[column] = le.fit_transform(df[column])\n    label_encoders[column] = le "

# %%
job_dict = {
  'admin.': 0,
	'unknown': 1,
	'unemployed': 2,
	'management': 3,
	'housemaid': 4,
	'entrepreneur': 5,
	'student': 6,
	'blue-collar': 7,
	'self-employed': 8,
	'retired': 9,
	'technician': 10,
	'services': 11
}

marital_dict = {
	'married': 0,
	'divorced': 1,
	'single': 2
}

education_dict = {
	'unknown': 0,
	'secondary': 1,
	'primary': 2,
	'tertiary': 3
}

default_dict = {
	'yes': 0,
	'no': 1
}

housing_dict = {
	'yes': 0,
	'no': 1
}

loan_dict = {
	'yes': 0,
	'no': 1
}

contact_dict = {
	'unknown': 0,
	'telephone': 1,
	'cellular': 2
}

month_dict = {
	'jan': 0,
	'feb': 1,
	'mar': 2,
	'apr': 3,
	'may': 4,
	'jun': 5,
	'jul': 6,
	'aug': 7,
	'sep': 8,
	'oct': 9,
	'nov': 10,
	'dec': 11
	}

poutcome_dict = {
	'unknown': 0,
	'other': 1,
	'failure': 2,
	'success': 3
	}

def map_column(data_column, mapping_dict):
	return np.array([mapping_dict[val.decode('utf-8')] for val in data_column])

# Mapeia as colunas categóricas usando os dicionários
job = map_column(data['job'], job_dict)
marital = map_column(data['marital'], marital_dict)
education = map_column(data['education'], education_dict)
default = map_column(data['default'], default_dict)
housing = map_column(data['housing'], housing_dict)
loan = map_column(data['loan'], loan_dict)
contact = map_column(data['contact'], contact_dict)
month = map_column(data['month'], month_dict)
poutcome = map_column(data['poutcome'], poutcome_dict)

# %%
age = np.asarray(data['age']).reshape(-1,1)
job = np.asarray(job).reshape(-1,1)
marital = np.asarray(marital).reshape(-1,1)
education = np.asarray(education).reshape(-1,1)
default = np.asarray(default).reshape(-1,1)
average = np.asarray(data['average']).reshape(-1,1)
housing = np.asarray(housing).reshape(-1,1)
loan = np.asarray(loan).reshape(-1,1)
contact = np.asarray(contact).reshape(-1,1)
day = np.asarray(data['day']).reshape(-1,1)
month = np.asarray(month).reshape(-1,1)
duration = np.asarray(data['duration']).reshape(-1,1)
campaign = np.asarray(data['campaign']).reshape(-1,1)
pdays = np.asarray(data['pdays']).reshape(-1,1)
previous = np.asarray(data['previous']).reshape(-1,1)
poutcome = np.asarray(poutcome).reshape(-1,1)

features = np.concatenate((age, job, marital, education, default, average, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome), axis=1)
target = data['subscribed']

# %%
Arvore = DecisionTreeClassifier(criterion='entropy').fit(features, target)

plt.figure(figsize=(10, 6.5))
tree.plot_tree(
    Arvore,
    feature_names=['age', 'job', 'marital', 'education', 'default', 'average', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous, poutcome','subscribed'],
    class_names=['yes', 'no'],
    filled=True, rounded=True
)
plt.show()

fig, ax = plt.subplots(figsize=(25, 10))
metrics.ConfusionMatrixDisplay.from_estimator(
    Arvore,
    features,
    target,
    display_labels=['yes', 'no'],
    values_format='d',
    ax=ax
)
plt.show()
# Out:
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# c:\Users\alvaro\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:348: FutureWarning: Support for labels represented as bytes is deprecated in v1.5 and will error in v1.7. Convert the labels to a string or integer format.
#   warnings.warn(
# ...
